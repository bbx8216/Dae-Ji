# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fc3_df = pd.read_csv('fc3.csv',encoding ='cp949')
fc4_df = pd.read_csv('fc4.csv',encoding ='cp949')
fc5_df = pd.read_csv('fc5.csv',encoding ='cp949')
fc6_df = pd.read_csv('fc6.csv',encoding ='cp949')
# Out:
# C:\Users\USER\Anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\USER\Anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
allFC_df = pd.concat([fc3_df,fc4_df, fc5_df, fc6_df])

# %%
#concatenate 한 df 를 csv 파일로 만들기
allFC_df.to_csv("allFC_df.csv")

# %%
allFC_df.loc[(allFC_df['CORP_ID']=='KX007'),'CORP_ID']='0'
allFC_df.loc[(allFC_df['CORP_ID']=='GP001'),'CORP_ID']='1'

# %%
allFC_df.drop(['REF_ORD_NO'],axis=1, inplace=True)
allFC_df.drop(['BKG_NO'],axis=1, inplace=True) 
allFC_df.drop(['REF_ITEM_SEQ'], axis=1, inplace = True)

# %%
allFC_df.drop(['SHPR_CD', 'ITEM_SEQ', 'BRAND_NM'],axis=1, inplace=True)
allFC_df.drop(['IF_YN','ORDER_CRT_DATETIME','INS_ID','INS_DATE','INS_TIME'],axis =1, inplace = True)
allFC_df= allFC_df.drop(['ORDER_IDX','ORDER_YN','DLVPREARREMPNICKNM'],axis =1, inplace = False)

# %%
allFC_df.isna()
# Out:
#         CORP_ID  BKG_TYP  BKG_DATE  BKG_TIME  INV_AMT  ITEM_CD  ITEM_QTY  \
# 0         False    False     False     False    False    False     False
# 1         False    False     False     False    False    False     False
# 2         False    False     False     False    False    False     False
# 3         False    False     False     False    False    False     False
# 4         False    False     False     False    False    False     False
# ...         ...      ...       ...       ...      ...      ...       ...
# 676907    False    False     False     False     True    False     False
# 676908    False    False     False     False     True    False     False
# 676909    False    False     False     False     True    False     False
# 676910    False    False     False     False     True    False     False
# 676911    False    False     False     False     True    False     False
#
#         ITEM_AMT  DLV_DV  DLVPREARRBRANCD  DLVCLSFCD  DLVSUBCLSFCD  POST_ZONE  \
# 0          False   False            False      False         False      False
# 1          False   False            False      False         False      False
# 2          False   False            False      False         False      False
# 3          False   False            False      False         False      False
# 4          False   False            False      False         False      False
# ...          ...     ...              ...        ...           ...        ...
# 676907      True   False            False      False         False      False
# 676908      True   False            False      False         False      False
# 676909      True   False            False      False         False      False
# 676910      True   False            False      False         False      False
# 676911      True   False            False      False         False      False
#
#         SPLIT_EXEC_YN  SHPR_ADDR_1  SHPR_ADDR_2  CNEE_ADDR_1  CNEE_ADDR_2
# 0               False        False         True        False        False
# 1               False        False        False        False        False
# 2               False        False        False        False        False
# 3               False        False        False        False        False
# 4               False        False        False        False        False
# ...               ...          ...          ...          ...          ...
# 676907          False        False        False        False         True
# 676908          False        False        False        False         True
# 676909          False        False        False        False         True
# 676910          False        False        False        False         True
# 676911          False        False        False        False         True
#
# [1786374 rows x 18 columns]

# %%
allFC_df.isna().sum() #칼럼별 NaN값 개수 확인 꺄악 다시 돌려버려서 다 0됨..ㅠㅠ
# Out:
# CORP_ID                 0
# BKG_TYP                 0
# BKG_DATE                0
# BKG_TIME                0
# INV_AMT             28011
# ITEM_CD                 0
# ITEM_QTY                0
# ITEM_AMT            18730
# DLV_DV               1043
# DLVPREARRBRANCD      1043
# DLVCLSFCD            1043
# DLVSUBCLSFCD         1150
# POST_ZONE            1043
# SPLIT_EXEC_YN           0
# SHPR_ADDR_1             0
# SHPR_ADDR_2        109251
# CNEE_ADDR_1            35
# CNEE_ADDR_2         35977
# dtype: int64

# %%
pd.DataFrame(allFC_df.isna().sum()).transpose()
# Out:
#    CORP_ID  BKG_TYP  BKG_DATE  BKG_TIME  INV_AMT  ITEM_CD  ITEM_QTY  ITEM_AMT  \
# 0        0        0         0         0    28011        0         0     18730
#
#    DLV_DV  DLVPREARRBRANCD  DLVCLSFCD  DLVSUBCLSFCD  POST_ZONE  SPLIT_EXEC_YN  \
# 0    1043             1043       1043          1150       1043              0
#
#    SHPR_ADDR_1  SHPR_ADDR_2  CNEE_ADDR_1  CNEE_ADDR_2
# 0            0       109251           35        35977

# %%
allFC_df['INV_AMT'] = allFC_df['INV_AMT'].fillna(allFC_df['INV_AMT'].mean())
allFC_df['ITEM_AMT'] = allFC_df['ITEM_AMT'].fillna(allFC_df['ITEM_AMT'].mean())

# %%
allFC_df.isna().sum()
# Out:
# CORP_ID                 0
# BKG_TYP                 0
# BKG_DATE                0
# BKG_TIME                0
# INV_AMT                 0
# ITEM_CD                 0
# ITEM_QTY                0
# ITEM_AMT                0
# DLV_DV               1043
# DLVPREARRBRANCD      1043
# DLVCLSFCD            1043
# DLVSUBCLSFCD         1150
# POST_ZONE            1043
# SPLIT_EXEC_YN           0
# SHPR_ADDR_1             0
# SHPR_ADDR_2        109251
# CNEE_ADDR_1            35
# CNEE_ADDR_2         35977
# dtype: int64

# %%
numerics=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_cols = allFC_df.select_dtypes(include = numerics).columns

# %%
allFC_df.loc[allFC_df[num_cols].isna().sum(axis=1)>0, num_cols].head()
# Out:
#        BKG_TYP  BKG_DATE  BKG_TIME       INV_AMT  ITEM_QTY      ITEM_AMT  \
# 22           8  20210302    184700  73518.623345      2080  53957.716636
# 41850        8  20210305     91535  73518.623345       480      0.000000
# 41851        8  20210305     91535  73518.623345       860      0.000000
# 41852        8  20210305     91535  73518.623345        72      0.000000
# 41853        8  20210305     91535  73518.623345       201      0.000000
#
#        DLV_DV  POST_ZONE
# 22        NaN        NaN
# 41850     NaN        NaN
# 41851     NaN        NaN
# 41852     NaN        NaN
# 41853     NaN        NaN

# %%
numerics=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

allFC_df[allFC_df.select_dtypes(include=numerics).columns] = allFC_df[allFC_df.select_dtypes(include=numerics).columns].fillna(0)

# %%
allFC_df.isna().sum()
# Out:
# CORP_ID                 0
# BKG_TYP                 0
# BKG_DATE                0
# BKG_TIME                0
# INV_AMT                 0
# ITEM_CD                 0
# ITEM_QTY                0
# ITEM_AMT                0
# DLV_DV                  0
# DLVPREARRBRANCD      1043
# DLVCLSFCD            1043
# DLVSUBCLSFCD         1150
# POST_ZONE               0
# SPLIT_EXEC_YN           0
# SHPR_ADDR_1             0
# SHPR_ADDR_2        109251
# CNEE_ADDR_1            35
# CNEE_ADDR_2         35977
# dtype: int64

# %% [markdown]
# DLV_DV(택배구분) / POST_ZONE(권역구분) -> 0으로 처리

# %%
not_num_cols = [x for x in allFC_df.columns if x not in num_cols]

allFC_df.loc[allFC_df[not_num_cols].isna().sum(axis=1)>0, not_num_cols].head()
# Out:
#    CORP_ID      ITEM_CD DLVPREARRBRANCD DLVCLSFCD DLVSUBCLSFCD SPLIT_EXEC_YN  \
# 0        0    134265392            7484      5Z73            1             N
# 7        0  603215395_1            M54T      6N20           1p             N
# 21       0    228550165            7484      5Z73            1             N
# 22       0       114585             NaN       NaN          NaN             N
# 24       0   3735258297            4830      4J30            1             N
#
#    SHPR_ADDR_1 SHPR_ADDR_2 CNEE_ADDR_1 CNEE_ADDR_2
# 0      세종특별자치시         NaN       서울특별시        서대문구
# 7      세종특별자치시         NaN       부산광역시         연제구
# 21     세종특별자치시         NaN       서울특별시        서대문구
# 22          경기         광주시          경기         광주시
# 24     세종특별자치시         NaN       서울특별시         관악구

# %%
allFC_df['SHPR_ADDR_2']= allFC_df['SHPR_ADDR_2'].fillna('S')
allFC_df['CNEE_ADDR_1']=allFC_df['CNEE_ADDR_1'].fillna('S')
allFC_df['CNEE_ADDR_2'] = allFC_df['CNEE_ADDR_2'].fillna('S')
allFC_df['DLVPREARRBRANCD'] = allFC_df['DLVPREARRBRANCD'].fillna('xxxxx')
allFC_df['DLVCLSFCD'] = allFC_df['DLVCLSFCD'].fillna('xxxxx')
allFC_df['DLVSUBCLSFCD'] = allFC_df['DLVSUBCLSFCD'].fillna('xxxxx')

# %%
allFC_df.isna().sum()
# Out:
# CORP_ID            0
# BKG_TYP            0
# BKG_DATE           0
# BKG_TIME           0
# INV_AMT            0
# ITEM_CD            0
# ITEM_QTY           0
# ITEM_AMT           0
# DLV_DV             0
# DLVPREARRBRANCD    0
# DLVCLSFCD          0
# DLVSUBCLSFCD       0
# POST_ZONE          0
# SPLIT_EXEC_YN      0
# SHPR_ADDR_1        0
# SHPR_ADDR_2        0
# CNEE_ADDR_1        0
# CNEE_ADDR_2        0
# dtype: int64

# %% [markdown]
# ### !!! 지역별 상품 수요량 파악하기 !!! - 예진아 파이팅

# %% [markdown]
# #### 1) 수화인 주소 통일하기.... 힘드렁

# %%
allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='서울시') | 
             (allFC_df['CNEE_ADDR_1']=='강서구') |
             (allFC_df['CNEE_ADDR_1']=='서울') |
             (allFC_df['CNEE_ADDR_1']=='마포구') |
             (allFC_df['CNEE_ADDR_1']=='영등포구') |
             (allFC_df['CNEE_ADDR_1']=='중구') |
             (allFC_df['CNEE_ADDR_1']=='?서울시') |
             (allFC_df['CNEE_ADDR_1']=='울특별시'), 'CNEE_ADDR_1']='서울특별시'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='강원'), 'CNEE_ADDR_1']='강원도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='경기') | 
             (allFC_df['CNEE_ADDR_1']=='경기도수원시') |
             (allFC_df['CNEE_ADDR_1']=='(12730)') |
             (allFC_df['CNEE_ADDR_1']=='곤지암') |
             (allFC_df['CNEE_ADDR_1']=='평택시') |
             (allFC_df['CNEE_ADDR_1']=='(13279)') |
             (allFC_df['CNEE_ADDR_1']=='(13499)') |
             (allFC_df['CNEE_ADDR_1']=='(14782)') |
             (allFC_df['CNEE_ADDR_1']=='[16817]') |
             (allFC_df['CNEE_ADDR_1']=='경기도시흥시') |
             (allFC_df['CNEE_ADDR_1']=='\t경기도') |
             (allFC_df['CNEE_ADDR_1']=='화성시'), 'CNEE_ADDR_1']='경기도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='경남') |
             (allFC_df['CNEE_ADDR_1']=='경삼남도') |
             (allFC_df['CNEE_ADDR_1']=='(53298)'), 'CNEE_ADDR_1']='경상남도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='경북') |
             (allFC_df['CNEE_ADDR_1']=='상주시') |
             (allFC_df['CNEE_ADDR_1']=='영천시') |
             (allFC_df['CNEE_ADDR_1']=='태종로711번길'), 'CNEE_ADDR_1']='경상북도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='광주'), 'CNEE_ADDR_1']='광주광역시'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='대구') |
             (allFC_df['CNEE_ADDR_1']=='대구시'), 'CNEE_ADDR_1']='대구광역시'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='대전'), 'CNEE_ADDR_1']='대전광역시'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='부산') |
             (allFC_df['CNEE_ADDR_1']=='부산시'), 'CNEE_ADDR_1']='부산광역시'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='인천') |
             (allFC_df['CNEE_ADDR_1']=='인천시') |
             (allFC_df['CNEE_ADDR_1']=='인천광역시?서구?정서진로?47') |
             (allFC_df['CNEE_ADDR_1']=='(22738)') |
             (allFC_df['CNEE_ADDR_1']=='인천광역시미추홀구'), 'CNEE_ADDR_1']='인천광역시'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='울산'), 'CNEE_ADDR_1']='울산광역시'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='전남') |
             (allFC_df['CNEE_ADDR_1']=='전남목포시'), 'CNEE_ADDR_1']='전라남도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='전북'), 'CNEE_ADDR_1']='전라북도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='충남') |
             (allFC_df['CNEE_ADDR_1']=='충남금산군') |
             (allFC_df['CNEE_ADDR_1']=='청남도'), 'CNEE_ADDR_1']='충청남도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='충북') |
             (allFC_df['CNEE_ADDR_1']=='청주시'), 'CNEE_ADDR_1']='충청북도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='제주'), 'CNEE_ADDR_1']='제주특별자치도'

allFC_df.loc[(allFC_df['CNEE_ADDR_1']=='세종') |
             (allFC_df['CNEE_ADDR_1']=='세종시') |
             (allFC_df['CNEE_ADDR_1']=='종시') |
             (allFC_df['CNEE_ADDR_1']=='(30100)'), 'CNEE_ADDR_1']='세종특별자치시'

# %% [markdown]
# #### 2) 그 이상한 주소 하나 버리기

# %%
idx = allFC_df[allFC_df['CNEE_ADDR_1']=='道路名稱首爾特別市中區麻將路1街22號（STUDIO'].index
allFC_df.drop(idx, inplace = True)

# %%
#idx2 = allFC_df[allFC_df['CNEE_ADDR_1']=='S'].index
#allFC_df.drop(idx2, inplace = True)

# %% [markdown]
# #### 3) 3시 반 드디어 groupby 시작

# %%
allFC_df_ext = allFC_df[['CNEE_ADDR_1', 'ITEM_CD','CORP_ID']]

# %%
allFC_df_groupby = allFC_df_ext.groupby(by=['CNEE_ADDR_1', 'ITEM_CD'])

# %%
allFC_df_groupby.count()
# Out:
#                             CORP_ID
# CNEE_ADDR_1 ITEM_CD
# S           10555566              1
#             18809566172065        4
#             4748857542_4          1
#             5406140018            1
#             6079851               1
# ...                             ...
# 충청북도        shop0001673           1
#             shop0001676           1
#             shop0001680           1
#             whole800001          18
#             whole800002          32
#
# [133022 rows x 1 columns]

# %% [markdown]
#  음...... 난 저 ITEM_CD를 column으로 하고싶은데,,,,,
#  얘들아 난 여기서 더 이상 저거를 컬럼으로 만들 자신이 없어.
#  우리 내일 열심히 토론해보자....
#  파이팅이다!!!

# %% [markdown]
# #### 4) pivot table로 해보기

# %%
allFC_df_pivot = pd.pivot_table(allFC_df_ext, index = 'CNEE_ADDR_1',
                               columns = 'ITEM_CD', values = 'CORP_ID',
                               aggfunc = 'count', fill_value = 0)

# %%
allFC_df_pivot
# Out:
# ITEM_CD      0001  0003  00062  00083  00085  00183  00210413  00224  00241  \
# CNEE_ADDR_1
# S               0     0      0      0      0      0         0      0      0
# 강원도            47     0      0      0      0      0         0      0      0
# 경기도           320     2      1      1      1      1         1      1      1
# 경상남도           93     0      0      0      0      0         0      0      0
# 경상북도           70     0      0      0      0      0         0      0      0
# 광주광역시          33     1      0      0      0      0         0      0      0
# 대구광역시          69     0      0      0      0      0         0      0      0
# 대전광역시          35     0      0      0      0      0         0      0      0
# 부산광역시          60     0      0      0      0      0         1      0      0
# 서울특별시         229     1      0      0      0      0         0      0      0
# 세종특별자치시         8     0      0      0      0      0         0      0      0
# 울산광역시          27     0      0      0      0      0         0      0      0
# 인천광역시          75     0      0      0      0      0         0      0      0
# 전라남도           47     0      0      0      0      0         0      0      0
# 전라북도           49     0      0      0      0      0         0      0      0
# 제주특별자치도         7     0      0      0      0      0         0      0      0
# 충청남도           51     0      0      0      0      0         0      0      0
# 충청북도           51     0      0      0      0      0         0      0      0
#
# ITEM_CD      00263  ...  shop0001673  shop0001674  shop0001675  shop0001676  \
# CNEE_ADDR_1         ...
# S                0  ...            0            0            0            0
# 강원도              0  ...            0            0            1            0
# 경기도              1  ...            3            0            3            6
# 경상남도             0  ...            0            0            0            2
# 경상북도             0  ...            0            0            0            0
# 광주광역시            0  ...            0            0            0            1
# 대구광역시            0  ...            0            0            0            2
# 대전광역시            0  ...            0            0            0            0
# 부산광역시            0  ...            1            1            0            1
# 서울특별시            0  ...            1            1            1            5
# 세종특별자치시          0  ...            0            0            0            0
# 울산광역시            0  ...            0            0            0            2
# 인천광역시            0  ...            0            0            0            1
# 전라남도             0  ...            1            0            0            0
# 전라북도             0  ...            1            0            0            0
# 제주특별자치도          0  ...            0            0            1            0
# 충청남도             0  ...            0            0            0            0
# 충청북도             0  ...            1            0            0            1
#
# ITEM_CD      shop0001677  shop0001678  shop0001679  shop0001680  whole800001  \
# CNEE_ADDR_1
# S                      0            0            0            0            0
# 강원도                    0            0            1            0           27
# 경기도                    1            2            2            1          241
# 경상남도                   0            2            1            0           77
# 경상북도                   0            0            0            0           41
# 광주광역시                  0            0            0            0           23
# 대구광역시                  0            0            0            0           39
# 대전광역시                  0            0            0            0           19
# 부산광역시                  1            0            0            0           63
# 서울특별시                  0            1            2            0          151
# 세종특별자치시                0            0            0            0            6
# 울산광역시                  1            0            0            0           13
# 인천광역시                  0            0            1            0           46
# 전라남도                   0            1            1            0           30
# 전라북도                   0            0            0            0           35
# 제주특별자치도                0            0            0            0            6
# 충청남도                   0            0            0            0           49
# 충청북도                   0            0            0            1           18
#
# ITEM_CD      whole800002
# CNEE_ADDR_1
# S                      0
# 강원도                   35
# 경기도                  333
# 경상남도                 110
# 경상북도                  79
# 광주광역시                 43
# 대구광역시                 57
# 대전광역시                 39
# 부산광역시                 91
# 서울특별시                230
# 세종특별자치시               12
# 울산광역시                 34
# 인천광역시                 61
# 전라남도                  66
# 전라북도                  44
# 제주특별자치도               22
# 충청남도                  57
# 충청북도                  32
#
# [18 rows x 16951 columns]

# %%
allFC_df_pivot['121174432_8']
# Out:
# CNEE_ADDR_1
# S            0
# 강원도         79
# 경기도        885
# 경상남도       218
# 경상북도       135
# 광주광역시      111
# 대구광역시      124
# 대전광역시      111
# 부산광역시      177
# 서울특별시      622
# 세종특별자치시     26
# 울산광역시       69
# 인천광역시      175
# 전라남도       109
# 전라북도       111
# 제주특별자치도     29
# 충청남도       124
# 충청북도        96
# Name: 121174432_8, dtype: int64

# %%
allFC_df_des = allFC_df_pivot.describe()
allFC_df_des
# Out:
# ITEM_CD        0001       0003      00062      00083      00085      00183  \
# count     18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean      70.611111   0.222222   0.055556   0.055556   0.055556   0.055556
# std       79.633823   0.548319   0.235702   0.235702   0.235702   0.235702
# min        0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%       33.500000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%       50.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%       69.750000   0.000000   0.000000   0.000000   0.000000   0.000000
# max      320.000000   2.000000   1.000000   1.000000   1.000000   1.000000
#
# ITEM_CD   00210413      00224      00241      00263  ...  shop0001673  \
# count    18.000000  18.000000  18.000000  18.000000  ...    18.000000
# mean      0.111111   0.055556   0.055556   0.055556  ...     0.444444
# std       0.323381   0.235702   0.235702   0.235702  ...     0.783823
# min       0.000000   0.000000   0.000000   0.000000  ...     0.000000
# 25%       0.000000   0.000000   0.000000   0.000000  ...     0.000000
# 50%       0.000000   0.000000   0.000000   0.000000  ...     0.000000
# 75%       0.000000   0.000000   0.000000   0.000000  ...     1.000000
# max       1.000000   1.000000   1.000000   1.000000  ...     3.000000
#
# ITEM_CD  shop0001674  shop0001675  shop0001676  shop0001677  shop0001678  \
# count      18.000000    18.000000    18.000000    18.000000    18.000000
# mean        0.111111     0.333333     1.166667     0.166667     0.333333
# std         0.323381     0.766965     1.757338     0.383482     0.685994
# min         0.000000     0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.000000     0.000000     0.000000     0.000000
# 50%         0.000000     0.000000     0.500000     0.000000     0.000000
# 75%         0.000000     0.000000     1.750000     0.000000     0.000000
# max         1.000000     3.000000     6.000000     1.000000     2.000000
#
# ITEM_CD  shop0001679  shop0001680  whole800001  whole800002
# count      18.000000    18.000000    18.000000    18.000000
# mean        0.444444     0.111111    49.111111    74.722222
# std         0.704792     0.323381    59.107966    81.826075
# min         0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.000000    18.250000    34.250000
# 50%         0.000000     0.000000    32.500000    50.500000
# 75%         1.000000     0.000000    48.250000    75.750000
# max         2.000000     1.000000   241.000000   333.000000
#
# [8 rows x 16951 columns]

# %%
allFC_df_max = allFC_df_des.loc['max',:]
allFC_df_max
# Out:
# ITEM_CD
# 0001           320.0
# 0003             2.0
# 00062            1.0
# 00083            1.0
# 00085            1.0
#                ...
# shop0001678      2.0
# shop0001679      2.0
# shop0001680      1.0
# whole800001    241.0
# whole800002    333.0
# Name: max, Length: 16951, dtype: float64

# %%
allFC_df_min = allFC_df_des.loc['min',:] # 각 품목의 최소개수
allFC_df_min1 = allFC_df_min[allFC_df_min==0] # 그 각 품목의 최소 개수가 0인 것 -> 해당되지 않는 나머지 1803개는 모든 지역에서 다 시키는 것
allFC_df_min1
# Out:
# ITEM_CD
# 0001           0.0
# 0003           0.0
# 00062          0.0
# 00083          0.0
# 00085          0.0
#               ...
# shop0001678    0.0
# shop0001679    0.0
# shop0001680    0.0
# whole800001    0.0
# whole800002    0.0
# Name: min, Length: 16947, dtype: float64

# %%
# 최소 개수가 0인 품목의 최대 개수
allFC_df_min2 = allFC_df_des.loc['max',allFC_df_min==0]
allFC_df_min2.describe()
# Out:
# count    16947.000000
# mean        30.570248
# std        128.479919
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%         17.000000
# max       7451.000000
# Name: max, dtype: float64

# %%
allFC_df_min2[allFC_df_min2 > 10]
# Out:
# ITEM_CD
# 0001           320.0
# 100026          44.0
# 100028          18.0
# 100032          35.0
# 100033          34.0
#                ...
# shop0001653     11.0
# shop0001658     14.0
# shop0001670     26.0
# whole800001    241.0
# whole800002    333.0
# Name: max, Length: 5464, dtype: float64

# %%
allFC_df_pivot['138632647_9']
# Out:
# CNEE_ADDR_1
# S            0
# 강원도         10
# 경기도        111
# 경상남도        24
# 경상북도        20
# 광주광역시       18
# 대구광역시       24
# 대전광역시       11
# 부산광역시       49
# 서울특별시      136
# 세종특별자치시      0
# 울산광역시        9
# 인천광역시       29
# 전라남도        19
# 전라북도        16
# 제주특별자치도      1
# 충청남도        13
# 충청북도         9
# Name: 138632647_9, dtype: int64

# %%
# 최소 개수가 0아 아닌 품목의 최대 개수 (모든 지역이 시키는 품목의 최대 개수)
allFC_df_min3 = allFC_df_des.loc['max',allFC_df_min!=0]
allFC_df_min3.describe()
# Out:
# count      4.00000
# mean     247.25000
# std       86.15635
# min      145.00000
# 25%      191.50000
# 50%      260.50000
# 75%      316.25000
# max      323.00000
# Name: max, dtype: float64

# %%
allFC_df_min3[allFC_df_min3<60]
# Out:
# Series([], Name: max, dtype: float64)

# %%
# 최소개수가 10개인 품목의 지역별 개수 -> 이걸 살릴지 말지 결정해야 할 듯
allFC_df_pivot['405135877_2']
# Out:
# CNEE_ADDR_1
# S           0
# 강원도         3
# 경기도         8
# 경상남도        3
# 경상북도        2
# 광주광역시       1
# 대구광역시       3
# 대전광역시       2
# 부산광역시       1
# 서울특별시      10
# 세종특별자치시     1
# 울산광역시       1
# 인천광역시       3
# 전라남도        1
# 전라북도        1
# 제주특별자치도     1
# 충청남도        2
# 충청북도        2
# Name: 405135877_2, dtype: int64

# %% [markdown]
# ## ---정리하겠습니다!---
#
# ### > 품목 개수 : 16933
# ### > 모든 지역에서 시키는 품목 개수 : 1803
# #### 그러면 이걸 다 살리느냐??? -> 1803개의 품목을 더 자세히 살펴봄
# 모든 지역이 다 시키지만 다 조금조금씩 시키는 품목도 있음
#
# ex) '405135877_2' 품목은 모든 지역에서 다 시키지만 최대 개수는 서울에서 시키는 10개임 (최대 10개, 최소 1개 시켰다는 말)
# ### > 최소 주문 개수가 0개인 품목 개수 : 15130 (모든 지역에서 다 시키지는 않는 품목)
# #### 이 15130개 품목 중에서 어떤 품목을 살릴 지 결정해야함 -> 자세히 살펴봄
# 이 품목들 중에서 75%는 전체 지역 통틀어서 시킨 개수의 최댓값이 10개임 (최대 10개, 최소 0개 시켰다는 말)
#
# 10개는 적으니깐 75% 버려도 되는거 아닌가? 라고 생각이 들 법도 하지만 위에서 예로 든 '405135877_2'품목을 살펴보면 그케 다르지 않음을 알 수 있음
#
# 그리고 최소 개수가 0개이지만 최대 개수가 582개인 품목도 있음 -> 이런건 그냥 한 지역에서만 안시킨 거지 무조건 포함되어야 하는 품목
#
# ### >>> 그렇다면 어떤 품목을 살리고, 어떤 품목을 버려야 할까? (생각해봐야할 거리를 던지겠습니다)
# 이건 진짜 너무 모르겠다....
# #### 우선 모든 지역에서 시키는 품목부터!
# 이것들을 다 살리기엔 각 지역에서 시키는 개수가 너무 적은 품목도 있음 (위에서 든 예시)
#
# 이 품목의 최대 개수를 살펴봤을 때
#
# mean      206.515807
#
# std       343.092177
#
# min        10.000000
#
# 25%        60.000000
#
# 50%       110.000000
#
# 75%       216.500000
#
# max      7451.000000
#
# 뭔가 어느 순간을 기준으로 숫자가 뻥 뛴다?는 느낌이 드는 기준이 애매함.
#
# 그렇다고 75%에서 끊기에는 216개라는 개수는 너무 많은 개수임.
# #### 모든 지역에서 다 시키지는 않는 품목은?
# 이 품목의 최대 개수를 살펴봤을 때
#
# mean         9.695704
#
# std         18.889171
#
# min          1.000000
#
# 25%          1.000000
#
# 50%          3.000000
#
# 75%         10.000000
#
# max        582.000000
#
# 이건 그나마 조금은 명확할 수도 있는게 최대 개수의 평균이 9개라는 건 어느 지역에서도 그렇게 많이 시키지는 않는다는 것.
#
# 그리고 75%랑 max의 숫자가 극명하게 차이나기 때문에, 75% 기준으로 끊는게 어느정도 타당할 수 있다고 생각함.
#
#
# ### 그래서 결론 --> 얘들아 도와줘

# %%
allFC_df_25 = allFC_df_des.loc['25%',:]
allFC_df_25
# Out:
# ITEM_CD
# 0001           33.50
# 0003            0.00
# 00062           0.00
# 00083           0.00
# 00085           0.00
#                ...
# shop0001678     0.00
# shop0001679     0.00
# shop0001680     0.00
# whole800001    18.25
# whole800002    34.25
# Name: 25%, Length: 16951, dtype: float64

# %% [markdown]
# ## 이제 지역별로 데이터를 쪼개 봅시다!

# %%
allFC_df
# Out:
#        CORP_ID  BKG_TYP  BKG_DATE  BKG_TIME       INV_AMT        ITEM_CD  \
# 0            0        7  20210303     35510  22400.000000      134265392
# 1            0        7  20210303     35521  20900.000000   4610261043_2
# 2            0        7  20210303     35513  37900.000000   4936599538_1
# 3            0        7  20210303     35608  69800.000000   3858391637_1
# 4            0        7  20210303     35551  73700.000000     4631307460
# ...        ...      ...       ...       ...           ...            ...
# 676907       1        7  20210628     91210  73518.623345          00281
# 676908       1        7  20210628     91210  73518.623345          00316
# 676909       1        7  20210628     91210  73518.623345          00338
# 676910       1        7  20210628     91210  73518.623345          00183
# 676911       1        7  20210628     91210  73518.623345  8809641651310
#
#         ITEM_QTY      ITEM_AMT  DLV_DV DLVPREARRBRANCD DLVCLSFCD DLVSUBCLSFCD  \
# 0              1  14900.000000     1.0            7484      5Z73            1
# 1              1  20900.000000     1.0            6427      6R67            4
# 2              1  37900.000000     1.0            6158      9Y25            0
# 3              1  69800.000000     1.0            8909      1N65            1
# 4              1  39800.000000     1.0            2777      3D84            1
# ...          ...           ...     ...             ...       ...          ...
# 676907       100  53957.716636     1.0            8981      5F20            1
# 676908       168  53957.716636     1.0            8981      5F20            1
# 676909       100  53957.716636     1.0            8981      5F20            1
# 676910        50  53957.716636     1.0            8981      5F20            1
# 676911       100  53957.716636     1.0            8981      5F20            1
#
#         POST_ZONE SPLIT_EXEC_YN SHPR_ADDR_1 SHPR_ADDR_2 CNEE_ADDR_1  \
# 0             3.0             N     세종특별자치시           S       서울특별시
# 1            50.0             N         경기도         광주시        경상남도
# 2            53.0             N         경기도         광주시        경상남도
# 3             6.0             N         경기도         광주시       서울특별시
# 4            10.0             N         경기도         광주시         경기도
# ...           ...           ...         ...         ...         ...
# 676907       10.0             N         경기도         군포시         경기도
# 676908       10.0             N         경기도         군포시         경기도
# 676909       10.0             N         경기도         군포시         경기도
# 676910       10.0             N         경기도         군포시         경기도
# 676911       10.0             N         경기도         군포시         경기도
#
#        CNEE_ADDR_2
# 0             서대문구
# 1              김해시
# 2              거제시
# 3              서초구
# 4              김포시
# ...            ...
# 676907           S
# 676908           S
# 676909           S
# 676910           S
# 676911           S
#
# [1786372 rows x 18 columns]

# %%
allFC_df['CNEE_ADDR_1'].unique()
# Out:
# array(['서울특별시', '경상남도', '경기도', '부산광역시', '대전광역시', '전라북도', '충청남도', '경상북도',
#        '인천광역시', '강원도', '전라남도', '대구광역시', '세종특별자치시', '충청북도', '울산광역시',
#        '광주광역시', '제주특별자치도', 'S'], dtype=object)

# %%
for i in allFC_df['CNEE_ADDR_1'].unique():
    FC_region = allFC_df[allFC_df['CNEE_ADDR_1']==i]
    FC_region.to_csv("FC_df_{}.csv".format(i), sep=',')

# %%
FC_df_서울특별시 = pd.read_csv('FC_df_서울특별시.csv')
FC_df_경상남도 = pd.read_csv('FC_df_경상남도.csv')
FC_df_경기도 = pd.read_csv('FC_df_경기도.csv')
FC_df_부산광역시 = pd.read_csv('FC_df_부산광역시.csv')
FC_df_대전광역시 = pd.read_csv('FC_df_대전광역시.csv')
FC_df_전라북도 = pd.read_csv('FC_df_전라북도.csv')
FC_df_충청남도 = pd.read_csv('FC_df_충청남도.csv')
FC_df_경상북도 = pd.read_csv('FC_df_경상북도.csv')
FC_df_인천광역시 = pd.read_csv('FC_df_인천광역시.csv')
FC_df_강원도 = pd.read_csv('FC_df_강원도.csv')
FC_df_전라남도 = pd.read_csv('FC_df_전라남도.csv')
FC_df_대구광역시 = pd.read_csv('FC_df_대구광역시.csv')
FC_df_세종특별자치시 = pd.read_csv('FC_df_세종특별자치시.csv')
FC_df_충청북도 = pd.read_csv('FC_df_충청북도.csv')
FC_df_울산광역시 = pd.read_csv('FC_df_울산광역시.csv')
FC_df_광주광역시 = pd.read_csv('FC_df_광주광역시.csv')
FC_df_제주특별자치도 = pd.read_csv('FC_df_제주특별자치도.csv')
FC_df_S = pd.read_csv('FC_df_S.csv')
# Out:
# C:\Users\USER\Anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\USER\Anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
FC_df_대구광역시
# Out:
#        Unnamed: 0  CORP_ID  BKG_TYP  BKG_DATE  BKG_TIME   INV_AMT  \
# 0              48        0        7  20210301      1051  178800.0
# 1              58        0        7  20210301      2909  200700.0
# 2              84        0        7  20210301      1445   29700.0
# 3             144        0        7  20210301       141   10900.0
# 4             187        0        7  20210301     10343   70400.0
# ...           ...      ...      ...       ...       ...       ...
# 76260      676686        0        7  20210630     81355   27900.0
# 76261      676714        1        7  20210630     95835   30000.0
# 76262      676745        1        7  20210630    100711   69000.0
# 76263      676753        1        7  20210630    100732   70000.0
# 76264      676873        0        7  20210630      3504  125800.0
#
#              ITEM_CD  ITEM_QTY  ITEM_AMT  DLV_DV DLVPREARRBRANCD DLVCLSFCD  \
# 0       4824189340_2         1  178800.0     1.0            K18A      5E30
# 1       4658408144_1         3  200700.0     1.0             766      5Z57
# 2          160659080         3   29700.0     1.0            K17V      5F40
# 3       4861386623_4         1   10900.0     1.0            7079      5Z59
# 4        550695708_9         1   70400.0     1.0            K18A      5E30
# ...              ...       ...       ...     ...             ...       ...
# 76260    232155349_1         1   27900.0     1.0            9310      5Z59
# 76261     5389247877         1   30000.0     1.0            8854      6R39
# 76262     2055185493         1   69000.0     1.0             766      5Z57
# 76263     4427993909         1   70000.0     1.0            7056      5E30
# 76264  5519470982_21         1  125800.0     1.0            K17V      5F40
#
#       DLVSUBCLSFCD  POST_ZONE SPLIT_EXEC_YN SHPR_ADDR_1 SHPR_ADDR_2  \
# 0               2t       42.0             N         경기도         광주시
# 1               2d       42.0             N         경기도         광주시
# 2               2t       42.0             N     세종특별자치시           S
# 3               0t       41.0             N         경기도         광주시
# 4               2t       42.0             N         경기도         광주시
# ...            ...        ...           ...         ...         ...
# 76260           1t       41.0             N         경기도         광주시
# 76261           1t       41.0             N     세종특별자치시           S
# 76262           2d       42.0             N     세종특별자치시           S
# 76263           00       41.0             N     세종특별자치시           S
# 76264           2t       42.0             N         경기도         광주시
#
#       CNEE_ADDR_1 CNEE_ADDR_2
# 0           대구광역시         수성구
# 1           대구광역시         달성군
# 2           대구광역시         달서구
# 3           대구광역시          북구
# 4           대구광역시         수성구
# ...           ...         ...
# 76260       대구광역시          북구
# 76261       대구광역시          동구
# 76262       대구광역시         달성군
# 76263       대구광역시          중구
# 76264       대구광역시         달서구
#
# [76265 rows x 19 columns]

# %% [markdown]
# ## 우선 품목 하나 떼어서 시간별 수요량을 파악해 봅시다!

# %%
item_date = allFC_df[['ITEM_CD', 'BKG_DATE']]
item_date
# Out:
#               ITEM_CD  BKG_DATE
# 0           134265392  20210303
# 1        4610261043_2  20210303
# 2        4936599538_1  20210303
# 3        3858391637_1  20210303
# 4          4631307460  20210303
# ...               ...       ...
# 676907          00281  20210628
# 676908          00316  20210628
# 676909          00338  20210628
# 676910          00183  20210628
# 676911  8809641651310  20210628
#
# [1786372 rows x 2 columns]

# %%
item01 = item_date[item_date['ITEM_CD']=='0001']
item01
# Out:
#        ITEM_CD  BKG_DATE
# 209818    0001  20210422
# 210345    0001  20210421
# 211494    0001  20210421
# 212053    0001  20210421
# 214057    0001  20210421
# ...        ...       ...
# 666927    0001  20210628
# 668560    0001  20210630
# 671456    0001  20210628
# 672889    0001  20210629
# 673334    0001  20210630
#
# [1271 rows x 2 columns]

# %%
item01_date = item01.groupby(by='BKG_DATE').count()
item01_date
# Out:
#           ITEM_CD
# BKG_DATE
# 20210421        8
# 20210422       17
# 20210423       15
# 20210424       12
# 20210425       17
# ...           ...
# 20210626        6
# 20210627       12
# 20210628       10
# 20210629       10
# 20210630       12
#
# [71 rows x 1 columns]

# %%
item01_date.plot()
plt.show()

# %%
all_item_date = item_date.groupby(['BKG_DATE', 'ITEM_CD'])
all_item_date_count = all_item_date.size()
all_item_date_count
# Out:
# BKG_DATE  ITEM_CD
# 20210301  100118          1
#           100119          3
#           100121         10
#           100123          6
#           100124          1
#                          ..
# 20210630  shop0001677     2
#           shop0001678     1
#           shop0001680     1
#           whole800001    21
#           whole800002    31
# Length: 304803, dtype: int64

# %%
all_item_date_unstack = all_item_date_count.unstack(fill_value=0)
all_item_date_unstack
# Out:
# ITEM_CD   0001  0003  00062  00083  00085  00183  00210413  00224  00241  \
# BKG_DATE
# 20210301     0     0      0      0      0      0         0      0      0
# 20210302     0     0      0      0      0      0         0      0      0
# 20210303     0     0      0      0      0      0         0      0      0
# 20210304     0     0      0      0      0      0         0      0      0
# 20210305     0     0      0      0      0      0         0      0      0
# ...        ...   ...    ...    ...    ...    ...       ...    ...    ...
# 20210626     6     0      0      0      0      0         0      0      0
# 20210627    12     0      0      0      0      0         0      0      0
# 20210628    10     0      1      1      1      1         0      1      1
# 20210629    10     0      0      0      0      0         0      0      0
# 20210630    12     0      0      0      0      0         0      0      0
#
# ITEM_CD   00263  ...  shop0001673  shop0001674  shop0001675  shop0001676  \
# BKG_DATE         ...
# 20210301      0  ...            0            0            0            0
# 20210302      0  ...            0            0            0            0
# 20210303      0  ...            0            0            0            0
# 20210304      0  ...            0            0            0            0
# 20210305      0  ...            0            0            0            0
# ...         ...  ...          ...          ...          ...          ...
# 20210626      0  ...            2            0            1            3
# 20210627      0  ...            0            0            1            3
# 20210628      1  ...            4            0            2            5
# 20210629      0  ...            1            0            0            2
# 20210630      0  ...            1            2            2            5
#
# ITEM_CD   shop0001677  shop0001678  shop0001679  shop0001680  whole800001  \
# BKG_DATE
# 20210301            0            0            0            0            0
# 20210302            0            0            0            0            0
# 20210303            0            0            0            0            0
# 20210304            0            0            0            0            0
# 20210305            0            0            0            0            0
# ...               ...          ...          ...          ...          ...
# 20210626            0            3            2            0           16
# 20210627            0            1            1            1           20
# 20210628            1            1            0            0           16
# 20210629            0            0            3            0           24
# 20210630            2            1            0            1           21
#
# ITEM_CD   whole800002
# BKG_DATE
# 20210301            0
# 20210302            0
# 20210303            0
# 20210304            0
# 20210305            0
# ...               ...
# 20210626           16
# 20210627           21
# 20210628           33
# 20210629           34
# 20210630           31
#
# [122 rows x 16951 columns]

# %%
i=0
while i < 20:
    all_item_date_unstack[i:i+1] = all_item_date_unstack[i:i+7].sum()
    all_item_date_unstack.drop(all_item_date_unstack.index[i+1:i+7], inplace = True)
    i += 1

# %%
all_item_date_unstack
# Out:
# ITEM_CD   0001  0003  00062  00083  00085  00183  00210413  00224  00241  \
# BKG_DATE
# 20210301     0     0      0      0      0      0         0      0      0
# 20210308     0     0      0      0      0      0         0      0      0
# 20210315     0     0      0      0      0      0         0      0      0
# 20210322     0     0      0      0      0      0         0      0      0
# 20210329     0     0      0      0      0      0         0      0      0
# 20210405     0     0      0      0      0      0         0      0      0
# 20210412     0     0      0      0      0      0         0      0      0
# 20210419    69     0      0      0      0      0         1      0      0
# 20210426   213     0      0      0      0      0         0      0      0
# 20210503   341     0      0      0      0      0         0      0      0
# 20210510   125     1      0      0      0      0         0      0      0
# 20210517    69     0      0      0      0      0         0      0      0
# 20210524    68     1      0      0      0      0         0      0      0
# 20210531   108     0      0      0      0      0         1      0      0
# 20210607    76     0      0      0      0      0         0      0      0
# 20210614    95     2      0      0      0      0         0      0      0
# 20210621    75     0      0      0      0      0         0      0      0
# 20210628    32     0      1      1      1      1         0      1      1
#
# ITEM_CD   00263  ...  shop0001673  shop0001674  shop0001675  shop0001676  \
# BKG_DATE         ...
# 20210301      0  ...            0            0            0            0
# 20210308      0  ...            0            0            0            0
# 20210315      0  ...            0            0            0            0
# 20210322      0  ...            0            0            0            0
# 20210329      0  ...            0            0            0            0
# 20210405      0  ...            0            0            0            0
# 20210412      0  ...            0            0            0            0
# 20210419      0  ...            0            0            0            0
# 20210426      0  ...            0            0            0            0
# 20210503      0  ...            0            0            0            0
# 20210510      0  ...            0            0            0            0
# 20210517      0  ...            0            0            0            0
# 20210524      0  ...            0            0            0            0
# 20210531      0  ...            0            0            0            0
# 20210607      0  ...            0            0            0            0
# 20210614      0  ...            0            0            0            0
# 20210621      0  ...            2            0            2            9
# 20210628      1  ...            6            2            4           12
#
# ITEM_CD   shop0001677  shop0001678  shop0001679  shop0001680  whole800001  \
# BKG_DATE
# 20210301            0            0            0            0            0
# 20210308            0            0            0            0            0
# 20210315            0            0            0            0            0
# 20210322            0            0            0            0            0
# 20210329            0            0            0            0            0
# 20210405            0            0            0            0            0
# 20210412            0            0            0            0            0
# 20210419            0            0            0            0            0
# 20210426            0            0            0            0            0
# 20210503            0            0            0            0            0
# 20210510            0            0            0            0            0
# 20210517            0            0            0            0            0
# 20210524            0            0            0            0           19
# 20210531            0            0            0            0          191
# 20210607            0            0            0            0          184
# 20210614            0            0            0            0          257
# 20210621            0            4            5            1          172
# 20210628            3            2            3            1           61
#
# ITEM_CD   whole800002
# BKG_DATE
# 20210301            0
# 20210308            0
# 20210315            0
# 20210322            0
# 20210329            0
# 20210405            0
# 20210412            0
# 20210419            0
# 20210426            0
# 20210503            0
# 20210510            0
# 20210517            0
# 20210524           48
# 20210531          368
# 20210607          293
# 20210614          316
# 20210621          222
# 20210628           98
#
# [18 rows x 16951 columns]

# %%
all_item_describe = all_item_date_unstack.describe()
all_item_describe
# Out:
# ITEM_CD        0001       0003      00062      00083      00085      00183  \
# count     18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean      70.611111   0.222222   0.055556   0.055556   0.055556   0.055556
# std       89.043373   0.548319   0.235702   0.235702   0.235702   0.235702
# min        0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%        0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%       68.500000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%       90.250000   0.000000   0.000000   0.000000   0.000000   0.000000
# max      341.000000   2.000000   1.000000   1.000000   1.000000   1.000000
#
# ITEM_CD   00210413      00224      00241      00263  ...  shop0001673  \
# count    18.000000  18.000000  18.000000  18.000000  ...    18.000000
# mean      0.111111   0.055556   0.055556   0.055556  ...     0.444444
# std       0.323381   0.235702   0.235702   0.235702  ...     1.464169
# min       0.000000   0.000000   0.000000   0.000000  ...     0.000000
# 25%       0.000000   0.000000   0.000000   0.000000  ...     0.000000
# 50%       0.000000   0.000000   0.000000   0.000000  ...     0.000000
# 75%       0.000000   0.000000   0.000000   0.000000  ...     0.000000
# max       1.000000   1.000000   1.000000   1.000000  ...     6.000000
#
# ITEM_CD  shop0001674  shop0001675  shop0001676  shop0001677  shop0001678  \
# count      18.000000    18.000000    18.000000    18.000000    18.000000
# mean        0.111111     0.333333     1.166667     0.166667     0.333333
# std         0.471405     1.028992     3.434256     0.707107     1.028992
# min         0.000000     0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.000000     0.000000     0.000000     0.000000
# 50%         0.000000     0.000000     0.000000     0.000000     0.000000
# 75%         0.000000     0.000000     0.000000     0.000000     0.000000
# max         2.000000     4.000000    12.000000     3.000000     4.000000
#
# ITEM_CD  shop0001679  shop0001680  whole800001  whole800002
# count      18.000000    18.000000    18.000000    18.000000
# mean        0.444444     0.111111    49.111111    74.722222
# std         1.338226     0.323381    86.309218   128.754123
# min         0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.000000     0.000000     0.000000
# 50%         0.000000     0.000000     0.000000     0.000000
# 75%         0.000000     0.000000    50.500000    85.500000
# max         5.000000     1.000000   257.000000   368.000000
#
# [8 rows x 16951 columns]

# %%
all_item_std = all_item_date_unstack.std()
all_item_std[all_item_std>1]
# Out:
# ITEM_CD
# 0001            89.043373
# 100026          10.562141
# 100027           1.084652
# 100028           5.533026
# 100032           6.181619
#                   ...
# shop0001676      3.434256
# shop0001678      1.028992
# shop0001679      1.338226
# whole800001     86.309218
# whole800002    128.754123
# Length: 9168, dtype: float64
